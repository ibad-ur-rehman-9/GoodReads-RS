# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
train_df = pd.read_csv("../data/processed/train.csv")
train_df.head()
# Out:
#                             user_id   book_id  rating
# 0  c82d3a24cf4c6afe923ee906451e7cd9   1499941       4
# 1  d7941b308469050c693713f00bd9206f     15645       5
# 2  e744432b77ec0a68d8cf9f0195e92698  19064137       3
# 3  2b90a2eadd6e47e50ab7c1e868a94262  16128095       4
# 4  06d2b1d9f173bc4a58824b138d67cc6d    491318       4

# %%
user_item_matrix = train_df.pivot_table(
    index='user_id',
    columns='book_id',
    values='rating',
    fill_value=0
)

user_item_matrix.shape
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 user_item_matrix = train_df.pivot_table(
#       2     index='user_id',
#       3     columns='book_id',
#       4     values='rating',
#       5     fill_value=0
#       6 )
#       8 user_item_matrix.shape
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
#    9517         dropna=dropna,
#    9518         margins_name=margins_name,
#    9519         observed=observed,
#    9520         sort=sort,
#    9521     )
#
# File C:\Anaconda\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File C:\Anaconda\Lib\site-packages\pandas\core\reshape\pivot.py:219, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     216         table = table.reindex(m, axis=1, fill_value=fill_value)
#     218 if sort is True and isinstance(table, ABCDataFrame):
# --> 219     table = table.sort_index(axis=1)
#     221 if fill_value is not None:
#     222     table = table.fillna(fill_value)
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:7379, in DataFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    7282 def sort_index(
#    7283     self,
#    7284     *,
#    (...)
#    7293     key: IndexKeyFunc | None = None,
#    7294 ) -> DataFrame | None:
#    7295     """
#    7296     Sort object by labels (along an axis).
#    7297
#    (...)
#    7377     d  4
#    7378     """
# -> 7379     return super().sort_index(
#    7380         axis=axis,
#    7381         level=level,
#    7382         ascending=ascending,
#    7383         inplace=inplace,
#    7384         kind=kind,
#    7385         na_position=na_position,
#    7386         sort_remaining=sort_remaining,
#    7387         ignore_index=ignore_index,
#    7388         key=key,
#    7389     )
#
# File C:\Anaconda\Lib\site-packages\pandas\core\generic.py:5317, in NDFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    5315     result = self
#    5316 else:
# -> 5317     result = self.copy(deep=None)
#    5319 if ignore_index:
#    5320     result.index = default_index(len(self))
#
# File C:\Anaconda\Lib\site-packages\pandas\core\generic.py:6811, in NDFrame.copy(self, deep)
#    6662 @final
#    6663 def copy(self, deep: bool_t | None = True) -> Self:
#    6664     """
#    6665     Make a copy of this object's indices and data.
#    6666
#    (...)
#    6809     dtype: int64
#    6810     """
# -> 6811     data = self._mgr.copy(deep=deep)
#    6812     self._clear_item_cache()
#    6813     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6814         self, method="copy"
#    6815     )
#
# File C:\Anaconda\Lib\site-packages\pandas\core\internals\managers.py:593, in BaseBlockManager.copy(self, deep)
#     590     else:
#     591         new_axes = list(self.axes)
# --> 593 res = self.apply("copy", deep=deep)
#     594 res.axes = new_axes
#     596 if self.ndim > 1:
#     597     # Avoid needing to re-compute these
#
# File C:\Anaconda\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File C:\Anaconda\Lib\site-packages\pandas\core\internals\blocks.py:796, in Block.copy(self, deep)
#     794 refs: BlockValuesRefs | None
#     795 if deep:
# --> 796     values = values.copy()
#     797     refs = None
#     798 else:
#
# MemoryError: Unable to allocate 9.24 GiB for an array with shape (20020, 61967) and data type float64

# %%
# Select top 3000 most-rated books
top_books = (
    train_df['book_id']
    .value_counts()
    .head(3000)
    .index
)

train_subset = train_df[train_df['book_id'].isin(top_books)]
train_subset.shape
# Out:
# (509954, 3)

# %%
# Optionally also limit users
top_users = (
    train_subset['user_id']
    .value_counts()
    .head(5000)
    .index
)

train_subset = train_subset[train_subset['user_id'].isin(top_users)]
train_subset.shape
# Out:
# (164454, 3)

# %%
user_item_matrix = train_subset.pivot_table(
    index='user_id',
    columns='book_id',
    values='rating',
    fill_value=0
)

user_item_matrix.shape
# Out:
# (5000, 2991)

# %%
from sklearn.metrics.pairwise import cosine_similarity

item_similarity = cosine_similarity(user_item_matrix.T)

item_similarity_df = pd.DataFrame(
    item_similarity,
    index=user_item_matrix.columns,
    columns=user_item_matrix.columns
)

item_similarity_df.iloc[:5, :5]
# Out:
# book_id       234     254       286       290       291
# book_id
# 234      1.000000  0.0392  0.000000  0.000000  0.026215
# 254      0.039200  1.0000  0.000000  0.000000  0.000000
# 286      0.000000  0.0000  1.000000  0.122600  0.033735
# 290      0.000000  0.0000  0.122600  1.000000  0.150482
# 291      0.026215  0.0000  0.033735  0.150482  1.000000

# %%
def predict_rating(user_id, book_id, user_item_matrix, item_similarity_df, k=10):
    """
    Predict rating of user_id for book_id using item-based CF
    """
    # If user or book not in matrix, return None
    if user_id not in user_item_matrix.index or book_id not in user_item_matrix.columns:
        return None

    # Get user's ratings
    user_ratings = user_item_matrix.loc[user_id]

    # Books rated by user
    rated_books = user_ratings[user_ratings > 0]

    if rated_books.empty:
        return None

    # Similarity scores for target book
    similarities = item_similarity_df[book_id]

    # Keep only books rated by user
    similarities = similarities[rated_books.index]

    # Select top-k similar books
    top_k = similarities.sort_values(ascending=False).head(k)

    # Weighted average
    numerator = np.dot(top_k.values, rated_books[top_k.index].values)
    denominator = np.sum(np.abs(top_k.values))

    if denominator == 0:
        return None

    return numerator / denominator

# %%
sample_user = user_item_matrix.index[0]
sample_book = user_item_matrix.columns[1]

predict_rating(sample_user, sample_book, user_item_matrix, item_similarity_df)

# %%
def recommend_books(user_id, user_item_matrix, item_similarity_df, k=10):
    """
    Recommend top-k books for a user
    """
    if user_id not in user_item_matrix.index:
        return []

    user_ratings = user_item_matrix.loc[user_id]

    # Books not rated by user
    unrated_books = user_ratings[user_ratings == 0].index

    predictions = []

    for book_id in unrated_books:
        pred = predict_rating(
            user_id, book_id,
            user_item_matrix,
            item_similarity_df
        )
        if pred is not None:
            predictions.append((book_id, pred))

    # Sort by predicted rating
    predictions.sort(key=lambda x: x[1], reverse=True)

    return predictions[:k]

# %%
recommend_books(sample_user, user_item_matrix, item_similarity_df, k=5)
# Out:
# [(22990, 5.0), (87047, 5.0), (133380, 5.0), (145659, 5.0), (150236, 5.0)]

# %%
#This freezes the model for the deployment
import pickle

with open("../models/user_item_matrix.pkl", "wb") as f:
    pickle.dump(user_item_matrix, f)

with open("../models/item_similarity.pkl", "wb") as f:
    pickle.dump(item_similarity_df, f)
